# %% [markdown]
# # Day 4: Spark Application **Deployment Modes** 🚀

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ### Today, we’ll explore the deployment modes of Spark applications. Understanding these modes is crucial for selecting the right environment for Spark jobs based on available resources and the specific requirements of each case.

# %% [markdown]
# ## What Are Deployment Modes?
# A Spark application can run in **two main deployment modes**: 𝗖𝗹𝗶𝗲𝗻𝘁 𝗠𝗼𝗱𝗲 and 𝗖𝗹𝘂𝘀𝘁𝗲𝗿 𝗠𝗼𝗱𝗲. Each mode determines the location of the Driver and Executors, as well as how they interact with the cluster's resources.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ **Client Mode**
#
# **Driver Location**: The Driver program runs on the local machine or client machine where the Spark application is submitted.
#
# **Use Case**: Best suited for development and testing in a local or small cluster environment.
#
# **How It Works**: The client machine launches the Spark job, but the actual data processing is performed on the Worker nodes. The Driver on the client is responsible for coordinating tasks.
#
# ✔️ Advantages:
#
# + Easy to debug and test.
#
# + Quick setup for small, on-the-spot jobs.
#
# ❌ Disadvantages:
#
# - Not recommended for production environments due to dependency on the client machine.
#
# - If the client disconnects, the Spark job may stop.

# %% [markdown]
# ## 2️⃣ Cluster Mode
# **Driver Location**: The Driver program runs inside the cluster, on one of the Worker nodes.
#
# **Use Case**: Ideal for production environments and larger clusters.
#
# **How It Works**: The Spark job is submitted to the Cluster Manager, which handles resource allocation and deploys the Driver on a Worker node.
#
# ✔️ Advantages:
#
# + Reliable for large and long-running applications.
# + Independent of the client once the job is submitted.
#
# ❌ Disadvantages:
#
# - Slightly more complex setup compared to Client Mode.
#
# - Harder to debug as the Driver logs are on remote cluster nodes.

# %% [markdown]
# ---

# %% [markdown]
# ## Key Takeaways
# **Client Mode**: Great for development and testing but less reliable for production.
#
# **Cluster Mode**: Best for production as the Spark application can run independently of the client.

# %% [markdown]
# ---

# %% [markdown]
# ###🚀 Tomorrow – RDD, DataFrame, and Dataset
# On Day 5, we’ll dive into Spark’s core data structures: RDDs, DataFrames, and Datasets. Stay tuned!
